# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from ydata_profiling import ProfileReport
# importing sweetviz
import sweetviz as sv

## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %%
import sys
# !{sys.executable} -m pip install -U ydata-profiling[notebook]
# !pip install jupyter-contrib-nbextensions
# Out:
# Requirement already satisfied: ydata-profiling[notebook] in c:\users\msala\anaconda3\lib\site-packages (4.9.0)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.11.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.0.3)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (3.7.2)
# Requirement already satisfied: pydantic>=2 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.8.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (3.1.2)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in c:\users\msala\anaconda3\lib\site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling[notebook]) (0.7.6)
# Requirement already satisfied: numpy<2,>=1.16.0 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.24.3)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (4.65.0)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.14.0)
# Requirement already satisfied: typeguard<5,>=3 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (4.3.0)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.57.1)
# Requirement already satisfied: jupyter>=1.0.0 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.0.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\msala\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (8.0.4)
# Requirement already satisfied: PyWavelets in c:\users\msala\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling[notebook]) (1.4.1)
# Requirement already satisfied: pillow in c:\users\msala\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling[notebook]) (9.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\msala\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (6.25.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\msala\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\msala\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\msala\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\msala\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\msala\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling[notebook]) (2.1.1)
# Requirement already satisfied: notebook in c:\users\msala\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.5.4)
# Requirement already satisfied: qtconsole in c:\users\msala\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (5.4.2)
# Requirement already satisfied: jupyter-console in c:\users\msala\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\msala\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.5.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\msala\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\msala\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\msala\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\msala\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\msala\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\msala\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\msala\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata-profiling[notebook]) (2.8.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\msala\anaconda3\lib\site-packages (from numba<1,>=0.56.0->ydata-profiling[notebook]) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msala\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling[notebook]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\msala\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling[notebook]) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\msala\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling[notebook]) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\msala\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\msala\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\msala\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\msala\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\msala\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\msala\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\msala\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (2023.7.22)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\msala\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling[notebook]) (0.5.3)
# Requirement already satisfied: colorama in c:\users\msala\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling[notebook]) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\msala\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling[notebook]) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\msala\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling[notebook]) (3.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\msala\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\msala\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\msala\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\msala\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\msala\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\msala\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (1.5.6)
# Requirement already satisfied: psutil in c:\users\msala\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\msala\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\msala\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (6.3.2)
# Requirement already satisfied: backcall in c:\users\msala\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.0)
# Requirement already satisfied: decorator in c:\users\msala\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\msala\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\msala\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\msala\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\msala\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\msala\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.0)
# Requirement already satisfied: six in c:\users\msala\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling[notebook]) (1.16.0)
# Requirement already satisfied: lxml in c:\users\msala\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.12.2)
# Requirement already satisfied: bleach in c:\users\msala\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\msala\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\msala\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.2.1)
# Requirement already satisfied: argon2-cffi in c:\users\msala\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (21.3.0)
# Requirement already satisfied: ipython-genutils in c:\users\msala\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\msala\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\msala\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\msala\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\msala\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.5)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\msala\anaconda3\lib\site-packages (from qtconsole->jupyter>=1.0.0->ydata-profiling[notebook]) (2.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\msala\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\msala\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\msala\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (305.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\msala\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\msala\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.2.2)
# Requirement already satisfied: fastjsonschema in c:\users\msala\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\msala\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.17.3)
# Requirement already satisfied: wcwidth in c:\users\msala\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\msala\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\msala\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\msala\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.4)
# Requirement already satisfied: webencodings in c:\users\msala\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.1)
# Requirement already satisfied: executing in c:\users\msala\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\msala\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\msala\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\msala\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\msala\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\msala\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\msala\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.15.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\msala\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\msala\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.21)
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: jupyter-contrib-nbextensions in c:\users\msala\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: ipython-genutils in c:\users\msala\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in c:\users\msala\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.4.2)
# Requirement already satisfied: jupyter-core in c:\users\msala\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (5.3.0)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in c:\users\msala\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in c:\users\msala\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in c:\users\msala\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (6.5.4)
# Requirement already satisfied: notebook>=6.0 in c:\users\msala\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (6.5.4)
# Requirement already satisfied: tornado in c:\users\msala\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (6.3.2)
# Requirement already satisfied: traitlets>=4.1 in c:\users\msala\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (5.7.1)
# Requirement already satisfied: lxml in c:\users\msala\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (4.9.3)
# Requirement already satisfied: setuptools in c:\users\msala\anaconda3\lib\site-packages (from jupyter-contrib-core>=0.3.3->jupyter-contrib-nbextensions) (68.0.0)
# Requirement already satisfied: jupyter-server in c:\users\msala\anaconda3\lib\site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.23.4)
# Requirement already satisfied: pyyaml in c:\users\msala\anaconda3\lib\site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (6.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (4.12.2)
# Requirement already satisfied: bleach in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.4)
# Requirement already satisfied: jinja2>=3.0 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (5.9.2)
# Requirement already satisfied: packaging in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (23.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\msala\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.2.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\msala\anaconda3\lib\site-packages (from jupyter-core->jupyter-contrib-nbextensions) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\msala\anaconda3\lib\site-packages (from jupyter-core->jupyter-contrib-nbextensions) (305.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\msala\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (23.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\msala\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\msala\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (7.4.9)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\msala\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (1.5.6)
# Requirement already satisfied: ipykernel in c:\users\msala\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (6.25.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\msala\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\msala\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\msala\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\msala\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (0.5.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\msala\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=6.0->jupyter-contrib-nbextensions) (2.8.2)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\msala\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\msala\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\msala\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.58.0)
# Requirement already satisfied: pywinpty in c:\users\msala\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.0.10)
# Requirement already satisfied: fastjsonschema in c:\users\msala\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\msala\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter-contrib-nbextensions) (4.17.3)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\msala\anaconda3\lib\site-packages (from argon2-cffi->notebook>=6.0->jupyter-contrib-nbextensions) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\msala\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\msala\anaconda3\lib\site-packages (from bleach->nbconvert>=6.0->jupyter-contrib-nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\msala\anaconda3\lib\site-packages (from bleach->nbconvert>=6.0->jupyter-contrib-nbextensions) (0.5.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\msala\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\msala\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\msala\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (8.15.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\msala\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (0.1.6)
# Requirement already satisfied: psutil in c:\users\msala\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (5.9.0)
# Requirement already satisfied: idna>=2.8 in c:\users\msala\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\msala\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.2.0)
# Requirement already satisfied: backcall in c:\users\msala\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: decorator in c:\users\msala\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\msala\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\msala\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\msala\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (3.0.36)
# Requirement already satisfied: stack-data in c:\users\msala\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: colorama in c:\users\msala\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (0.4.6)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\msala\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter-contrib-nbextensions) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\msala\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter-contrib-nbextensions) (0.18.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\msala\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter-contrib-nbextensions) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\msala\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter-contrib-nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\msala\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\msala\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.5)
# Requirement already satisfied: executing in c:\users\msala\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\msala\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\msala\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.2)
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install sweetviz
# Out:
# Collecting sweetvizNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading sweetviz-2.3.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\msala\anaconda3\lib\site-packages (from sweetviz) (2.0.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\msala\anaconda3\lib\site-packages (from sweetviz) (1.24.3)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\msala\anaconda3\lib\site-packages (from sweetviz) (3.7.2)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\msala\anaconda3\lib\site-packages (from sweetviz) (4.65.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\msala\anaconda3\lib\site-packages (from sweetviz) (1.11.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users
#    -------------------------------------- - 14.7/15.1 MB 764.8 kB/s eta 0:00:01
#    -------------------------------------- - 14.7/15.1 MB 766.6 kB/s eta 0:00:01
#    ---------------------------------------  14.7/15.1 MB 764.8 kB/s eta 0:00:01
#    ---------------------------------------  14.8/15.1 MB 767.5 kB/s eta 0:00:01
#    ---------------------------------------  14.8/15.1 MB 766.7 kB/s eta 0:00:01
#    ---------------------------------------  14.9/15.1 MB 766.6 kB/s eta 0:00:01
#    ---------------------------------------  14.9/15.1 MB 765.8 kB/s eta 0:00:01
#    ---------------------------------------  15.0/15.1 MB 765.8 kB/s eta 0:00:01
#    ---------------------------------------  15.0/15.1 MB 763.9 kB/s eta 0:00:01
#    ---------------------------------------  15.1/15.1 MB 763.1 kB/s eta 0:00:01
#    ---------------------------------------  15.1/15.1 MB 764.0 kB/s eta 0:00:01
#    ---------------------------------------  15.1/15.1 MB 763.9 kB/s eta 0:00:01
#    ---------------------------------------- 15.1/15.1 MB 761.2 kB/s eta 0:00:00
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-6.4.0 sweetviz-2.3.1

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
df = pd.read_csv("data_saudi_used_cars.csv")

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
df.head(20)
# Out:
#             Type          Region        Make  Gear_Type       Origin  \
# 0        Corolla            Abha      Toyota     Manual        Saudi
# 1          Yukon          Riyadh         GMC  Automatic        Saudi
# 2    Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 3         Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 4             FJ          Riyadh      Toyota  Automatic        Saudi
# 5            CX3            Abha       Mazda  Automatic        Saudi
# 6      Cayenne S          Riyadh     Porsche  Automatic        Saudi
# 7         Sonata          Riyadh     Hyundai  Automatic        Saudi
# 8         Avalon          Riyadh      Toyota  Automatic        Saudi
# 9             LS           Aseer       Lexus  Automatic        Saudi
# 10          C300          Makkah    Chrysler  Automatic        Saudi
# 11  Land Cruiser          Riyadh      Toyota  Automatic        Saudi
# 12            LS          Dammam       Lexus  Automatic        Saudi
# 13            FJ          Riyadh      Toyota  Automatic        Saudi
# 14         Hilux           Yanbu      Toyota  Automatic        Saudi
# 15  Land Cruiser           Aseer      Toyota     Manual  Gulf Arabic
# 16  Land Cruiser         Al-Baha      Toyota     Manual        Saudi
# 17  Land Cruiser          Riyadh      Toyota  Automatic        Saudi
# 18        Tucson          Jeddah     Hyundai  Automatic        Saudi
# 19       Caprice          Riyadh   Chevrolet  Automatic        Other
#
#       Options  Year  Engine_Size  Mileage  Negotiable   Price
# 0    Standard  2013          1.4   421000        True       0
# 1        Full  2014          8.0    80000       False  120000
# 2        Full  2015          5.0   140000       False  260000
# 3   Semi Full  2015          2.4   220000       False   42000
# 4        Full  2020          4.0    49000        True       0
# 5   Semi Full  2019          2.0    25000       False   58000
# 6        Full  2012          4.8   189000       False   85000
# 7        Full  2016          2.4      155       False   48000
# 8    Standard  2016          3.5   110864       False   81500
# 9        Full  1998          4.6      300        True       0
# 10       Full  2013          5.7      200       False   55000
# 11       Full  2011          4.6    79000       False  145000
# 12       Full  2008          4.6   299000       False   38000
# 13  Semi Full  2020          4.0    17000       False  140000
# 14       Full  2014          2.7      209        True       0
# 15  Semi Full  1982          4.6   340000        True       0
# 16  Semi Full  1985          2.0    30000        True       0
# 17       Full  2019          4.6    71000       False  200000
# 18   Standard  2018          2.0    85000       False   65000
# 19   Standard  1983          1.0   500000        True       0

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
# profile = ProfileReport(df0, title="Pandas Profiling Report")
advert_report = sv.analyze(df2)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
advert_report.show_html('Advertising.html')
# Out:
# Report Advertising.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")
profile
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 profile = ProfileReport(df, title="Pandas Profiling Report")
#       2 profile
#
# NameError: name 'ProfileReport' is not defined

# %%
# Out:
# Report Advertising.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
# the data was scrapped from syarah.com therefore the data is reliable

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %%
#the data is for the year 2023 its not up to date but it will do the purpose of this projectabs

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %%
#the data is consistent with the datasource
# Out:
# array(['Toyota', 'GMC', 'Land Rover', 'Kia', 'Mazda', 'Porsche',
#        'Hyundai', 'Lexus', 'Chrysler', 'Chevrolet', 'Nissan',
#        'Mitsubishi', 'Ford', 'MG', 'Mercedes', 'Jeep', 'BMW', 'Audi',
#        'Lincoln', 'Cadillac', 'Genesis', 'Renault', 'Honda', 'Suzuki',
#        'Zhengzhou', 'Dodge', 'HAVAL', 'INFINITI', 'Isuzu', 'Changan',
#        'Aston Martin', 'Mercury', 'Great Wall', 'Other', 'Rolls-Royce',
#        'MINI', 'Volkswagen', 'BYD', 'Geely', 'Victory Auto', 'Classic',
#        'Jaguar', 'Daihatsu', 'Maserati', 'Hummer', 'GAC', 'Lifan',
#        'Bentley', 'Chery', 'Peugeot', 'Foton', 'Škoda', 'Fiat', 'Iveco',
#        'SsangYong', 'FAW', 'Tata', 'Ferrari'], dtype=object)

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %%
#Yes the data is reliable from the sample prospective
#Yes the data is reliable from the variable prospective

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
# There is duplicates row but it is ok becuase a car with the same specification can appear more than one

# %%
# go to delete duplicates columns

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
#Display number missing values per column
#there is no missing values

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
# check columns types 
#the data types are as needed for each column
df.dtypes
# Out:
# Type            object
# Region          object
# Make            object
# Gear_Type       object
# Origin          object
# Options         object
# Year             int64
# Engine_Size    float64
# Mileage          int64
# Negotiable        bool
# Price            int64
# dtype: object

# %%
# go to clean them

# %%
# check outliers

# %% [markdown]
# **What is an Outlier?**
# Outlier is an row/observation that appears far away and diverges from an overall pattern in a sample.
#
# **What are the types of Outliers?**
# 1. Univariate: These outliers can be found when we look at distribution of a single variable
# 2. Multivariate: are outliers in an n-dimensional space. In order to find them, you have to look at distributions in multi-dimensions. example (hight=100, weight=100) for a person
#
# **What causes Outliers?**
# Whenever we come across outliers, the ideal way to tackle them is to find out the reason of having these outliers. The method to deal with them would then depend on the reason of their occurrence.
#
# Let’s understand various types of outliers:
#
# 1. Data Entry Errors:- Human errors such as errors caused during data collection, recording, or entry can cause outliers in data.
# 2. Measurement Error: It is the most common source of outliers. This is caused when the measurement instrument used turns out to be faulty.
# 3. Data Processing Error: Whenever we perform data mining, we extract data from multiple sources. It is possible that some manipulation or extraction errors may lead to outliers in the dataset.
# 4. Sampling error: For instance, we have to measure the height of athletes. By mistake, we include a few basketball players in the sample. This inclusion is likely to cause outliers in the dataset.
# 5. Natural Outlier: When an outlier is not artificial (due to error), it is a natural outlier. For instance: In my last assignment with one of the renowned insurance company, I noticed that the performance of top 50 financial advisors was far higher than rest of the population. Surprisingly, it was not due to any error. Hence, whenever we perform any data mining activity with advisors, we used to treat this segment separately.
#
#
# **What is the impact of Outliers on a dataset?**
#
#
# ![image.png](https://www.analyticsvidhya.com/wp-content/uploads/2015/02/Outlier_31.png)
#
#
#
# **How to detect Outliers?**
#
# 1. Most commonly used method to detect outliers is visualization (Univariate Graphical Analysis).
#
# We use 3 common visualization methods:
# >- Box-plot: A box plot is a method for graphically depicting groups of numerical data through their quartiles. The box extends from the Q1 to Q3 quartile values of the data, with a line at the median (Q2). The whiskers extend from the edges of the box to show the range of the data. Outlier points are those past the end of the whiskers. Box plots show robust measures of location and spread as well as providing information about symmetry and outliers.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:698/format:webp/1*VK5iHA2AB28HSZwWwUbNYg.png)
# >
# >
# >- Histogram
# >- Scatter Plot: A scatter plot is a mathematical diagram using Cartesian coordinates to display values for two variables for a set of data. The data are displayed as a collection of points, each having the value of one variable determining the position on the horizontal axis and the value of the other variable determining the position on the vertical axis. The points that are far from the population can be termed as an outlier.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:4800/format:webp/1*Ov6aH-8yIwNoUxtMFwgx4g.png)
# >
# >
#
# 2. Using statistical method (Univariate Non-Graphical analysis):
# >- Any value, which is beyond the range of -1.5 x IQR to 1.5 x IQR
#
# ![image.png](https://www.whatissixsigma.net/wp-content/uploads/2015/07/Box-Plot-Diagram-to-identify-Outliers-figure-1.png)
#
# >- Use capping methods. Any value which out of range of 5th and 95th percentile can be considered as outlier
# >- Data points, three or more standard deviation away from mean are considered outlier: The Z-score is the signed number of standard deviations by which the value of an observation or data point is above the mean value of what is being observed or measured. While calculating the Z-score we re-scale and center the data and look for data points that are too far from zero. These data points which are way too far from zero will be treated as the outliers. In most of the cases, a threshold of 3 or -3 is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.
# > - Outlier detection is merely a special case of the examination of data for influential data points and it also depends on the business understanding

# %%
# go to univariate graphical analysis
# go to lesson : data visualisation 1 - chart type section
# then go to univariate graphical analysis
# detect outliers using graphs varbaly

# %%
# go to lesson: statistics 1 then statistics 3
# then go to univariate Non graphical analysis
# detect outliers using numerical statistics

# %%
df0 = df[df['Price'] == 0]
df0
# Out:
#               Type  Region     Make  Gear_Type       Origin    Options  Year  \
# 0          Corolla    Abha   Toyota     Manual        Saudi   Standard  2013
# 4               FJ  Riyadh   Toyota  Automatic        Saudi       Full  2020
# 9               LS   Aseer    Lexus  Automatic        Saudi       Full  1998
# 14           Hilux   Yanbu   Toyota  Automatic        Saudi       Full  2014
# 15    Land Cruiser   Aseer   Toyota     Manual  Gulf Arabic  Semi Full  1982
# ...            ...     ...      ...        ...          ...        ...   ...
# 5610      Town Car  Jeddah  Lincoln  Automatic        Other       Full  1999
# 5614      Victoria  Makkah     Ford  Automatic        Saudi   Standard  2010
# 5617         Yukon  Jubail      GMC  Automatic        Saudi  Semi Full  2006
# 5620        Altima  Jeddah   Nissan  Automatic        Saudi  Semi Full  2020
# 5623            ES  Jeddah    Lexus  Automatic        Other       Full  2017
#
#       Engine_Size  Mileage  Negotiable  Price
# 0             1.4   421000        True      0
# 4             4.0    49000        True      0
# 9             4.6      300        True      0
# 14            2.7      209        True      0
# 15            4.6   340000        True      0
# ...           ...      ...         ...    ...
# 5610          5.0      343        True      0
# 5614          4.6   345000        True      0
# 5617          5.3      300        True      0
# 5620          2.5    58000        True      0
# 5623          3.5   115000        True      0
#
# [1797 rows x 11 columns]

# %%
# go to delete ouliers
df1 = df[df['Price'] > 0]
df1
# Out:
#              Type          Region        Make  Gear_Type       Origin  \
# 1           Yukon          Riyadh         GMC  Automatic        Saudi
# 2     Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 3          Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 5             CX3            Abha       Mazda  Automatic        Saudi
# 6       Cayenne S          Riyadh     Porsche  Automatic        Saudi
# ...           ...             ...         ...        ...          ...
# 5616          CX9          Qassim       Mazda  Automatic        Saudi
# 5618     Suburban          Riyadh         GMC  Automatic        Saudi
# 5619      X-Trail          Jeddah      Nissan  Automatic        Saudi
# 5621        Yukon          Dammam         GMC  Automatic        Saudi
# 5622           RX          Dammam       Lexus  Automatic  Gulf Arabic
#
#         Options  Year  Engine_Size  Mileage  Negotiable   Price
# 1          Full  2014          8.0    80000       False  120000
# 2          Full  2015          5.0   140000       False  260000
# 3     Semi Full  2015          2.4   220000       False   42000
# 5     Semi Full  2019          2.0    25000       False   58000
# 6          Full  2012          4.8   189000       False   85000
# ...         ...   ...          ...      ...         ...     ...
# 5616       Full  2020          2.0     9500       False  132000
# 5618       Full  2006          5.3    86000       False   50000
# 5619   Standard  2018          2.5    78794       False   68000
# 5621       Full  2016          5.3    48000       False  145000
# 5622       Full  2016          2.5    81000       False  154000
#
# [3827 rows x 11 columns]

# %%
df1 = df1[df1['Engine_Size'] < 7]
df1
# Out:
#              Type          Region        Make  Gear_Type       Origin  \
# 2     Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 3          Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 5             CX3            Abha       Mazda  Automatic        Saudi
# 6       Cayenne S          Riyadh     Porsche  Automatic        Saudi
# 7          Sonata          Riyadh     Hyundai  Automatic        Saudi
# ...           ...             ...         ...        ...          ...
# 5616          CX9          Qassim       Mazda  Automatic        Saudi
# 5618     Suburban          Riyadh         GMC  Automatic        Saudi
# 5619      X-Trail          Jeddah      Nissan  Automatic        Saudi
# 5621        Yukon          Dammam         GMC  Automatic        Saudi
# 5622           RX          Dammam       Lexus  Automatic  Gulf Arabic
#
#         Options  Year  Engine_Size  Mileage  Negotiable   Price
# 2          Full  2015          5.0   140000       False  260000
# 3     Semi Full  2015          2.4   220000       False   42000
# 5     Semi Full  2019          2.0    25000       False   58000
# 6          Full  2012          4.8   189000       False   85000
# 7          Full  2016          2.4      155       False   48000
# ...         ...   ...          ...      ...         ...     ...
# 5616       Full  2020          2.0     9500       False  132000
# 5618       Full  2006          5.3    86000       False   50000
# 5619   Standard  2018          2.5    78794       False   68000
# 5621       Full  2016          5.3    48000       False  145000
# 5622       Full  2016          2.5    81000       False  154000
#
# [3722 rows x 11 columns]

# %%
df1 = df[df['Price'] > 5000 ]
df2 = df[(df['Price'] < 5000) & (df['Price'] > 0)]

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %% [markdown]
# ### Handling missing values:

# %% [markdown]
# **Why my data has missing values?**
# They may occur at two stages:
# 1. Data Extraction: It is possible that there are problems with extraction process. Errors at data extraction stage are typically easy to find and can be corrected easily as well.
# 2. Data collection: These errors occur at time of data collection and are harder to correct.
#
# **Why do we need to handle the missing data?**
# To avoid:
# - Bias the conclusions.
# - Leading the business to make wrong decisions.
#
# **Which are the methods to treat missing values ?**
# 1. Deletion: we delete rows where any of the variable is missing. Simplicity is one of the major advantage of this method, but this method reduces the power of model because it reduces the sample size.
#
# 2. Imputation: is a method to fill in the missing values with estimated ones. This imputation is one of the most frequently used methods.
#
#     2.1. Mean/ Mode/ Median Imputation: It consists of replacing the missing data for a given attribute by the mean or median (quantitative attribute) or mode (qualitative attribute) of all known values of that variable.
#     > It can be of two types:
#     > - Generalized Imputation: In this case, we calculate the mean or median for all non missing values of that variable then replace missing value with mean or median.
#     > - Similar case Imputation: In this case, we calculate average for each group individually of non missing values then replace the missing value based on the group.
#
#     2.2. Constant Value
#
#     2.3. Forward Filling
#
#     2.4. Backward Filling
#
# 6. Prediction Model:  Prediction model is one of the sophisticated method for handling missing data. Here, we create a predictive model to estimate values that will substitute the missing data.  In this case, we divide our data set into two sets: One set with no missing values for the variable and another one with missing values. First data set become training data set of the model while second data set with missing values is test data set and variable with missing values is treated as target variable. Next, we create a model to predict target variable based on other attributes of the training data set and populate missing values of test data set.
#
# > There are 2 drawbacks for this approach:
# > - The model estimated values are usually more well-behaved than the true values
# > - If there are no relationships with attributes in the data set and the attribute with missing values, then the model will not be precise for estimating missing values.
#
# 9. KNN Imputation: In this method of imputation, the missing values of an attribute are imputed using the given number of attributes that are most similar to the attribute whose values are missing. The similarity of two attributes is determined using a distance function. It is also known to have certain advantage & disadvantages.
#
#    > **Advantages:**
#    > - k-nearest neighbour can predict both qualitative & quantitative attributes
#    > - Creation of predictive model for each attribute with missing data is not required
#    > - Attributes with multiple missing values can be easily treated
#    > - Correlation structure of the data is taken into consideration
#
#    > **Disadvantage:**
#    > - KNN algorithm is very time-consuming in analyzing large database. It searches through all the dataset looking for the most similar instances.
#    > - Choice of k-value is very critical. Higher value of k would include attributes which are significantly different from what we need whereas lower value of k implies missing out of significant attributes.
#
# --------------------

# %%
# go back to 6th dimention --> Completeness

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %% [markdown]
# ## 3. Univariate Analysis:
#
# This involves examining single variables to understand their characteristics (distribution, central tendency, dispersion, and shape).
#
# We calculate **numerical values** about the data that tells us about the distribution of the data. We also **draw graphs** showing visually how the data is distributed. **To answer the following questions about Features/characteristics of Data:**
# - Where is the center of the data? (location)
# - How much does the data vary? (scale)
# - What is the shape of the data? (shape)
#
# **The benefits of this analysis:**
# Statistics summary gives a high-level idea to identify whether the data has any outliers, data entry error, distribution of data such as the data is normally distributed or left/right skewed
#
# **In this step, we will explore variables one by one using following approaches:**

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %%
plt.boxplot(df['Engine_Size'])
plt.show()

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %% [markdown]
# **Categorical & Categorical --> (Stacked Column Chart)**

# %% [markdown]
# **Categorical & numerical --> (scatter plot, histogram, box plot)**

# %% [markdown]
# **numerical & numerical --> (Scatter plot, line chart)**

# %% [markdown]
# We could also use a correlation matrix to get more specific information about the relationship between these two variables.

# %%
correlation_matrix = cars.corr()
print(correlation_matrix)
plt.figure(figsize=(6, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, vmin=-1, vmax=1)
plt.title('Correlation Matrix of Used Car Data')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 correlation_matrix = cars.corr()
#       2 print(correlation_matrix)
#       3 plt.figure(figsize=(6, 6))
#
# NameError: name 'cars' is not defined
